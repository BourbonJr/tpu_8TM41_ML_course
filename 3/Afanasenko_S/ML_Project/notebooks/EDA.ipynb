# %%
plt.figure(figsize=(8, 6))
sns.lineplot(x='n_student', y='posttest', data=df)
plt.title('Зависимость posttest от количества учеников в классе')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='school_type', y='posttest', data=df)
plt.title('Среднее значение posttest для разных типов школ')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.drop('gender_num', axis=1).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Корреляция числовых признаков")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='posttest', hue='gender', kde=True)
plt.title('Распределение posttest для разных полов (гистограмма)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='n_student', y='posttest', data=df)
plt.xlabel('Количество учеников в классе')
plt.ylabel('Оценка за posttest')
plt.title('Среднее значение posttest для разного количества учеников в классе')
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(x='school', y='posttest', data=df, estimator='mean')  # estimator='mean' показывает среднее значение
plt.xlabel('Школа')
plt.ylabel('Оценка за posttest')
plt.title('Среднее значение posttest для каждой школы')
plt.xticks(rotation=45, ha='right')  # Повернем названия школ для лучшей читаемости
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='teaching_method', y='posttest', data=df)
plt.xlabel('Метод обучения')
plt.ylabel('Оценка за posttest')
plt.title('Среднее значение posttest для каждого метода обучения')
plt.show()

# %%
sns.histplot(df['posttest'], bins=20, kde=True)
plt.title('Распределение оценок posttest')
plt.show()

# %%
# Список категориальных признаков
categorical_columns = ['school', 'school_setting', 'school_type', 'classroom', 
                       'teaching_method', 'gender', 'lunch']

for col in categorical_columns:
    print(f"{col}: {df[col].nunique()} уникальных значений")
    print(df[col].value_counts(), "\n")
# Out:
# school: 23 уникальных значений
# school
# GOOBU    147
# QOQTS    134
# UKPGS    118
# DNQDD    110
# ZOWMK    109
# GJJHK    107
# VVTVA    107
# CCAAW    102
# KZKKE    100
# CUQAM     99
# VKWQH     95
# IDGFP     86
# UUUQX     83
# UAGPU     80
# OJOBU     77
# CIMBB     70
# ZMNYA     65
# GOKXL     60
# LAYPA     55
# KFZMY     51
# VHDHF     47
# FBUMG     44
# ANKYI     38
# Name: count, dtype: int64
#
# school_setting: 3 уникальных значений
# school_setting
# Urban       841
# Suburban    665
# Rural       478
# Name: count, dtype: int64
#
# school_type: 2 уникальных значений
# school_type
# Public        1463
# Non-public     521
# Name: count, dtype: int64
#
# classroom: 97 уникальных значений
# classroom
# 18K    29
# ZBH    29
# 7BL    28
# 0N7    28
# Q0E    28
#        ..
# G2L    15
# P2A    14
# JGD    14
# SSP    14
# 197    13
# Name: count, Length: 97, dtype: int64
#
# teaching_method: 2 уникальных значений
# teaching_method
# Standard        1274
# ...

# %%
print(df.describe())
# Out:
#          n_student      pretest    posttest
# count  1984.000000  1984.000000  1984.00000
# mean     22.769153    54.980847    67.12500
# std       4.248477    13.558027    13.93532
# min      14.000000    22.000000    32.00000
# 25%      20.000000    44.000000    56.00000
# 50%      22.000000    56.000000    68.00000
# 75%      27.000000    65.000000    77.00000
# max      31.000000    93.000000   100.00000

# %%
# Размер набора данных
print(f"Размер данных: {df.shape}")

# Основная информация о данных
print(df.info())

# Проверка пропущенных значений
print(df.isnull().sum())
# Out:
# Размер данных: (1984, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1984 entries, 0 to 1983
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school           1984 non-null   object
#  1   school_setting   1984 non-null   object
#  2   school_type      1984 non-null   object
#  3   classroom        1984 non-null   object
#  4   teaching_method  1984 non-null   object
#  5   n_student        1984 non-null   float64
#  6   student_id       1984 non-null   object
#  7   gender           1984 non-null   object
#  8   lunch            1984 non-null   object
#  9   pretest          1984 non-null   float64
#  10  posttest         1984 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 170.6+ KB
# None
# school             0
# school_setting     0
# school_type        0
# classroom          0
# teaching_method    0
# n_student          0
# student_id         0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/test_scores.csv')  # Подгружаем данные
print(df.head())  # Вывод первых строк
# Out:
#   school school_setting school_type classroom teaching_method  n_student  \
# 0  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4  ANKYI          Urban  Non-public       6OL        Standard       20.0
#
#   student_id  gender             lunch  pretest  posttest
# 0      2FHT3  Female  Does not qualify     62.0      72.0
# 1      3JIVH  Female  Does not qualify     66.0      79.0
# 2      3XOWE    Male  Does not qualify     64.0      76.0
# 3      556O0  Female  Does not qualify     61.0      77.0
# 4      74LOE    Male  Does not qualify     64.0      76.0
